# %%
print("HOPE AI")
# Out:
# HOPE AI

# %%
name=input("Enter your institute name?:")
# Out:
# Enter your institute name?: HOPE AI

# %%
name=input("Enter your name:")
age=input("Enter your age:")
school=input("Enter your school:")
degree=input("Enter your degree:")
# Out:
# Enter your name: Nithyanandham
# Enter your age: 43
# Enter your school: M.M.A.Govt.School, Pallavaram
# Enter your degree: DME'

# %%
##**Addition**

# %%
a = 43
b = 34
add = a+b
print(add)
# Out:
# 77

# %%
##--

# %%
##**Substraction**

# %%
a = 43
b = 34
sub = a-b
print(sub)
# Out:
# 9

# %%
##**Multiplication**

# %%
a = 63
b = 97
mul = a*b
print(mul)
# Out:
# 6111

# %%
##**Division**

# %%
a = 76
b = 31
div = a/b
print("Float Div=", div)
# Out:
# Float Div= 2.4516129032258065

# %%
##**Floor Division**

# %%
a = 76
b = 31
div = a//b
print("Floor Div=", div)
# Out:
# Floor Div= 2

# %%
##**Modulo**

# %%
a = 76
b = 31
div = a%b
print("Modulo=", div)
# Out:
# Modulo= 14

# %%
##**Power**

# %%
a = 4
b = 4
mul = a**b
print("Power=", mul)
# Out:
# Power= 256
