# %%
# ** print function **

# print function uses is, if provide anything to inside of ("xx"), we can get that printout as it is. See below the examples.

# %%
print("I love my india")
# Out:
# I love my india

# %%
print("'Believe yourself'")
# Out:
# 'Believe yourself'

# %%
print("My name is 'Nithyanandham'")
print("I am working in 'steel detailing' around '18 years overall experiance'")
print("I am the 'project Leader' in the current working concern")
print("I am completed my current concern '11 years successfully'")
# Out:
# My name is 'Nithyanandham'
# I am working in 'steel detailing' around '18 years overall experiance'
# I am the 'project Leader' in the current working concern
# I am completed my current concern '11 years successfully'

# %%
# Note: ()= open bracket/ open parantheses.  [] = closed bracket/ square bracket.  {} = flower bracket/ curly braces

# %%
#  **

# %%
# ** Variable function / Assignment operator **

# %%
# number=100  -  Text is calling variable (L.H.S), = is calling Assignment operator, number is calling inputs (R.H.S).

# %%
# All the inputs will be tacken "Line by line" method. Variable color is always 'Black' A.O. color is 'Lavendar'

# %%
# Variable function / Assignment operator examples below:

# %%
num1=25
num2=50
add=num1+num2
print(add)
# Out:
# 75

# %%
num1=20
num2=30
Addtion=num1+num2
print("Addtion", (add))
# Out:
# Addtion 75

# %%
#  **

# %%
# First assingment:

# %%
print("The addition of two numbers")
number1=25
print("The number 1 is:",number1)
number2=75
print("The number 2 is:",number2)
print("The answer is:",number1+number2)
# Out:
# The addition of two numbers
# The number 1 is: 25
# The number 2 is: 75
# The answer is: 100

# %%
#  **

# %%
# Note: When enter the values, must check all the inputs are correct.. Like, (), case sensetive, text inputs, =  etc....

# %%
# If anything misses inputs then we will get errors like, Syntex, Name error, EOF = End Of File, etc....

# %%
# Rool-1: If we type the inputs, we should be use text in correct order to understand to see the later.

# %%
# We should avoid to use a1,b1,c1. instead of that, use number1, number2, number3.
# And also use the topic in heading is much better.

# %%
# Rool-2: When we input the text (Variable) you've to follow text without space like "firstName", "First_number", etc...
# If you use space like, "first name" you should be get name error. And also should be not use number in first like "5thing",
# instead of this you can use "t5hing".

# When we get the errors, should be read what kind of errors having in the programme. Based on that, need to fix the errors.

# %%
#  **

# %%
# input function.

# %%
num1=input("enter the num1:")
# Out:
# enter the num1: 50

# %%
num2=input("enter the num2:")
# Out:
# enter the num2: 30

# %%
add=num1+num2
print(add)
# Out:
# 5030

# %%
#  **

# %%
num1=int(input("enter the num1:"))
# Out:
# enter the num1: 60

# %%
num2=int(input("enter the num2:"))
# Out:
# enter the num2: 30

# %%
add=num1+num2
print(add)
# Out:
# 90

# %%
name=str(input("enter the name:"))
# Out:
# enter the name: Nithyanandham M

# %%
# **

# %%
num1=int(input("enter the num1"))
# Out:
# enter the num1 100

# %%
num2=int(input("enter the num2"))
# Out:
# enter the num2 200

# %%
print(num1+num2)
# Out:
# 300

# %%
# **

# %%
# Excercise:1 Required output is **The substraction of two numbers** The num1 value is =100, The num2 value is = 20.
# The final answer is = 80.

# %%
print("The substraction of two numbers")
num1=100
print("The num1 value is:", num1)
num2=20
print("The num2 value is:", num2)
sub=num1-num2
print("The final answer is:", sub)
# Out:
# The substraction of two numbers
# The num1 value is: 100
# The num2 value is: 20
# The final answer is: 80

# %%
# **

# %%
# Excercise:2 Required output is **The multiplication of two numbers** The num1 value is =100, The num2 value is = 20.
# The final answer is = 2000.

# %%
print("The multiplication of two numbers")
num1=100
print("The num1 value is:", num1)
num2=20
print("The num2 value is:", num2)
mul=num1*num2
print("The final answer is:", mul)
# Out:
# The multiplication of two numbers
# The num1 value is: 100
# The num2 value is: 20
# The final answer is: 2000

# %%
#**

# %%
# Excercise:3 Required output is **The Division of two numbers** The num1 value is =100, The num2 value is = 20.
# The final answer is = 5.0.

# %%
print("The Division of two numbers")
num1=100
print("The num1 value is:", num1)
num2=20
print("The num2 value is:", num2)
div=num1/num2
print("The final answer is:", div)
# Out:
# The Division of two numbers
# The num1 value is: 100
# The num2 value is: 20
# The final answer is: 5.0
